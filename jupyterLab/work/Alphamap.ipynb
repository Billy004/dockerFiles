# %%
#pip install -U leafmap earthengine-api ipywidgets jupyterlab_widgets ipyvuetify

# %%
import ee
import leafmap.maplibregl as leafmap

# %%
ee.Authenticate(auth_mode="notebook")
ee.Initialize(project="alphamap-474009")
print(ee.String('Hello from the Earth Engine servers!').getInfo())
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=B3tEvubC0ux9b4iGNHCjpJ7H7M-K9ukrC3fbZZ7-3Cc&tc=sbm2j63tTL95UCrVtHL0V7rAwv6pG8LxrEQ3gNoAmrs&cc=D3-6sEEaAe2eCcrJtgDQ5nNamL3Y6rsEFA8S3oP3Z4k>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=B3tEvubC0ux9b4iGNHCjpJ7H7M-K9ukrC3fbZZ7-3Cc&tc=sbm2j63tTL95UCrVtHL0V7rAwv6pG8LxrEQ3gNoAmrs&cc=D3-6sEEaAe2eCcrJtgDQ5nNamL3Y6rsEFA8S3oP3Z4k</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AVGzR1B08VnlIlaSTPqiOsyWtMXFCRjifLhwRU5Wn7WzLKHgdVDJLXwoNIk
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ee.Authenticate(auth_mode="notebook")
#       2 ee.Initialize(project="alphamap-474009")
#       3 print(ee.String('Hello from the Earth Engine servers!').getInfo())
#
# File /opt/conda/lib/python3.11/site-packages/ee/__init__.py:159, in Authenticate(authorization_code, quiet, code_verifier, auth_mode, scopes, force)
#     128 def Authenticate(
#     129     authorization_code: Optional[str] = None,
#     130     quiet: Optional[bool] = None,
#    (...)
#     134     force: bool = False,
#     135 ) -> Optional[bool]:
#     136   """Prompts the user to authorize access to Earth Engine via OAuth2.
#     137
#     138   Args:
#    (...)
#     157     True if we found valid credentials and didn't run the auth flow.
#     158   """
# --> 159   return oauth.authenticate(authorization_code, quiet, code_verifier, auth_mode,
#     160                             scopes, force)
#
# File /opt/conda/lib/python3.11/site-packages/ee/oauth.py:553, in authenticate(cli_authorization_code, quiet, cli_code_verifier, auth_mode, scopes, force)
#     550 if flow.display_instructions(quiet):
#     551   _open_new_browser(flow.auth_url)
# --> 553 flow.save_code()
#
# File /opt/conda/lib/python3.11/site-packages/ee/oauth.py:603, in Flow.save_code(self, code)
#     601   redirect_uri = self.server.url
#     602   code = self.server.fetch_code()  # Waits for oauth callback
# --> 603 _obtain_and_write_token(code, self.code_verifier, self.scopes, redirect_uri)
#
# File /opt/conda/lib/python3.11/site-packages/ee/oauth.py:270, in _obtain_and_write_token(auth_code, code_verifier, scopes, redirect_uri)
#     267 fetched_info = json.loads(
#     268     urllib.request.urlopen(fetch_client).read().decode())
#     269 if 'error' in fetched_info:
# --> 270   raise ee_exception.EEException(
#     271       'Cannot authenticate: %s' % fetched_info['error']
#     272   )
#     273 client_info = {k: fetched_info[k] for k in ['client_id', 'client_secret']}
#     274 scopes = fetched_info.get('scopes') or scopes
#
# EEException: Cannot authenticate: Invalid request.

# %%
m = leafmap.Map(projection="globe", sidebar_visible=True)
m.add_basemap("USGS.Imagery")
m.add_alphaearth_gui()
m

# %%
m = leafmap.Map(projection="globe", sidebar_visible=True)
m.add_basemap("USGS.Imagery")

# %%
lon = -121.8036
lat = 39.0372
m.set_center(lon, lat, zoom=12)

# %%
point = ee.Geometry.Point(lon, lat)
dataset = ee.ImageCollection("GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL")

# %%
image1 = dataset.filterDate("2017-01-01", "2018-01-01").filterBounds(point).first()
image2 = dataset.filterDate("2024-01-01", "2025-01-01").filterBounds(point).first()

# %%
vis_params = {"min": -0.3, "max": 0.3, "bands": ["A01", "A16", "A09"]}
m.add_ee_layer(image1, vis_params, name="Year 1 embeddings")
m.add_ee_layer(image2, vis_params, name="Year 2 embeddings")

# %%
dot_prod = image1.multiply(image2).reduce(ee.Reducer.sum())

# %%
vis_params = {"min": 0, "max": 1, "palette": ["white", "black"]}
m.add_ee_layer(dot_prod, vis_params, name="Similarity")
